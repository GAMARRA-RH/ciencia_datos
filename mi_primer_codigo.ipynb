# %% [markdown]
# <a href="https://colab.research.google.com/github/GAMARRA-RH/ciencia_datos/blob/main/mi_primer_codigo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre="carlos"
edad= 18
print(f"hola {nombre}, tu edad es {edad}")
# Out:
# hola carlos, tu edad es 18

# %%
numero1=30
numero2=10
resta=numero1 - numero2
print(f"el resultado de la resta es: {resta} ")
# Out:
# el resultado de la resta es: 20

# %%
edades=[18,20,19,22,8,21]
total_esudiantes=len(edades)
suma_edades=sum(edades)
print(f"el grupo tiene un total de {total_esudiantes} estudiantes")
print(f"promedio de edades: {round(suma_edades/total_esudiantes,1)}")
# Out:
# el grupo tiene un total de 6 estudiantes
# promedio de edades: 18.0
